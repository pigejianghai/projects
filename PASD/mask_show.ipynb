# %%
import matplotlib.pyplot as plt
import numpy as np

path = '/data1/jianghai/open_source/neoadjuvant/ViTransformers/multi_task/npy_MT_placenta_mask/MR0431396.npy'
array = np.load(path)

# print(array.shape)
arr = array[..., 0]
plt.imshow(arr, cmap='gray')
